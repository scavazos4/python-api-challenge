# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
#!pip install citipy
from pprint import pprint
import random
from citipy import citipy

# %%
#open file with country codes
#need to run below code in console to increase limit to perform
#list compilation 
#jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10
cityID = []


f= open("WeatherPy/CityID.json", encoding="utf8")
data = json.loads(f.read())
for i in data:
    cityID.append(i)

# %%
#converting to data frame to isolate country IDs
df = pd.DataFrame(cityID)
IDs = df["id"]
allIDs = IDs.astype(int)


selectedCities = allIDs.sample(n=600)
selectedCities = selectedCities.tolist()

#converting to str to be applicable to URL
selectedCities = map(str, selectedCities)

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?id="
units = "imperial"

# Build partial query URL
query_url = f"&appid={wkey}&units={units}&q="

# %%
#attempt at loop
city = []
lat = [] 
long = []
temp = [] 
humidty = [] 
speed = []
cloudiness = []

for cityS in selectedCities:
    response = requests.get(url + cityS + query_url).json()
    city.append(response['name'])
    lat.append(response["coord"]["lat"])
    long.append(response["coord"]["lon"])
    temp.append(response["main"]["temp"])
    humidty.append(response["main"]["humidity"])
    speed.append(response["wind"]["speed"])
    cloudiness.append(response["clouds"]["all"])

# %%
weatherDict = {
    "city": city,
    "lat": lat,
    "lon": long,
    "temp": temp,
    "humidity (%)": humidty,
    "wind speed": speed,
    "cloudiness (%)": cloudiness
}

weatherData = pd.DataFrame(weatherDict)
weatherData.head(20)
# Out:
#                        city      lat       lon   temp  humidity (%)  \
# 0              Chiddingfold  51.1187   -0.6226  55.35            47
# 1                   Trignac  47.3181   -2.1890  62.35            45
# 2                      Orio  43.2787   -2.1254  58.21            87
# 3            Agía Paraskeví  38.0167   23.8333  62.92            45
# 4                  Nyasvizh  53.2181   26.6725  37.20            81
# 5          Garrafe de Torío  42.7371   -5.5129  52.99            87
# 6                Monticello  36.8298  -84.8491  77.50            47
# 7                 Lucindale -36.9833  140.3667  49.41            89
# 8                Thalhausen  50.5000    7.5833  52.12            39
# 9                    Jijila  45.3000   28.1500  48.11            76
# 10                 Bānswāra  23.5500   74.4500  87.03            27
# 11                    Žalec  46.2515   15.1648  43.16            95
# 12                 Labuleng  35.2012  102.5212  30.20            59
# 13                  Luorong  24.4058  109.6086  63.21            91
# 14                Drovyanoy  72.4017   72.7625  31.55            99
# 15                   Rhoose  51.3978   -3.3492  52.48            62
# 16             Little Chute  44.2800  -88.3184  51.80            58
# 17  Mazra‘at Muḩammad Aḩmad  34.5500   38.3167  67.57            49
# 18                Strážnice  48.9010   17.3168  51.78            35
# 19                  Quaqtaq  61.0337  -69.6147  24.80            80
#
#     wind speed  cloudiness (%)
# 0         3.44              62
# 1         9.22               0
# 2         5.35              95
# 3        13.80              20
# 4         6.64              95
# 5         2.30              75
# 6        21.85               1
# 7         3.18              12
# 8         3.00              17
# 9        12.66              75
# 10        3.89              49
# 11        2.24             100
# 12        1.79              79
# 13        3.80              95
# 14        8.05             100
# 15       10.36              62
# 16       10.80              75
# 17       17.47               0
# 18        8.05               0
# 19        8.05              20

# %%
#temp vs lat
ax1 = weatherData.plot.scatter(x = "temp",y = "lat")
ax1.set_title("Temperature vs Latitude")

# this analysis the comparison of temperature and latitide
# Out:
# Text(0.5, 1.0, 'Temperature vs Latitude')

# %%
#hum vs lat
ax2 = weatherData.plot.scatter(x = "humidity (%)", y = "lat")
ax2.set_title("Humidity vs Latitude")

# this analysis the comparison of humidity and latitude
# Out:
# Text(0.5, 1.0, 'Humidity vs Latitude')

# %%
#cloudiness vs lat
ax3= weatherData.plot.scatter(x = "cloudiness (%)", y="lat")
ax3.set_title("cloudiness vs latitude")

# this analysis the comparison of cloudiness vs latitude
# Out:
# Text(0.5, 1.0, 'cloudiness vs latitude')

# %%
#winspeed vs lat
ax4 = weatherData.plot.scatter(x = "wind speed", y = "lat")
ax4.set_title("winspeed vs lat")

# this analysis the comparison of windspeed vs latitude
# Out:
# Text(0.5, 1.0, 'winspeed vs lat')

# %%
#splitting data into above and below equator
northernCities = weatherData.loc[weatherData["lat"] >= 0, :]
southernCities = weatherData.loc[weatherData["lat"] < 0 , :]

# %%
#temp vs lat Northern
Nax1 = northernCities.plot.scatter(x = "temp",y = "lat")
Nax1.set_title("Temperature vs Latitude")
# Out:
# Text(0.5, 1.0, 'Temperature vs Latitude')

# %%
#Humid vs lat Northern
Nax2 = northernCities.plot.scatter(x = "humidity (%)", y = "lat")
Nax2.set_title("Humidity vs Latitude")
# Out:
# Text(0.5, 1.0, 'Humidity vs Latitude')

# %%
#Clouds vs lat Northern
Nax3 = northernCities.plot.scatter(x = "cloudiness (%)", y = "lat")
Nax3.set_title("Cloudiness vs Latitude")
# Out:
# Text(0.5, 1.0, 'Cloudiness vs Latitude')

# %%
#WindSpeed vs lat Northern
Nax4 = northernCities.plot.scatter(x = "wind speed", y = "lat")
Nax4.set_title("Wind Speed vs Latitude")
# Out:
# Text(0.5, 1.0, 'Wind Speed vs Latitude')

# %%
Sax4 = southernCities.plot.scatter(x = "temp", y = "lat")
Sax4.set_title("temp vs Latitude")
# Out:
# Text(0.5, 1.0, 'temp vs Latitude')
